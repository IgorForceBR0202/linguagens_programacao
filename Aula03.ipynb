# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorForceBR0202/linguagens_programacao/blob/main/Aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ANÁLISE DE QUALIDADE DO AR NO BRASIL COM PYTHON**

# %% [markdown]
# **PARTE I PREPARAÇÃO DO AMBIENTE**

# %%
import pandas as pd

# %% [markdown]
# **Carregando o dataset:**

# %%
df = pd.read_csv('/content/qualidade_ar_brasil.csv')

# %% [markdown]
# **PARTE II - INSPEÇÃO**

# %%
df.shape
df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data                 800 non-null    object
#  1   cidade               800 non-null    object
#  2   estado               800 non-null    object
#  3   pm25                 800 non-null    float64
#  4   pm10                 800 non-null    float64
#  5   no2                  800 non-null    float64
#  6   o3                   800 non-null    float64
#  7   temperatura          800 non-null    float64
#  8   umidade              800 non-null    float64
#  9   indice_qualidade_ar  800 non-null    float64
#  10  nivel_alerta         800 non-null    object
# dtypes: float64(7), object(4)
# memory usage: 68.9+ KB
# data                   0
# cidade                 0
# estado                 0
# pm25                   0
# pm10                   0
# no2                    0
# o3                     0
# temperatura            0
# umidade                0
# indice_qualidade_ar    0
# nivel_alerta           0
# dtype: int64

# %%
df['cidade'].unique()
# Out:
# array(['Brasília', 'Curitiba', 'Salvador', 'Belo Horizonte', 'Recife',
#        'Fortaleza', 'Rio de Janeiro', 'Porto Alegre', 'Manaus',
#        'São Paulo'], dtype=object)

# %%
df.shape[0]
# Out:
# 800

# %%
df.isnull().sum()
# Out:
# data                   0
# cidade                 0
# estado                 0
# pm25                   0
# pm10                   0
# no2                    0
# o3                     0
# temperatura            0
# umidade                0
# indice_qualidade_ar    0
# nivel_alerta           0
# dtype: int64

# %% [markdown]
# # **Perguntas**
# # 1. Quantas medições existem no dataset?
# R: 800 Medições
#
# 2. Quantas cidades estão presentes na base?
# R: 10 cidades
#
# 3. Quais colunas representam poluentes atmosféricos?
# R:
#
# 4. Existem valores ausentes no dataset?
# R: Não existem valores ausentes

# %% [markdown]
# # **PARTE III - ANÁLISE POR CIDADE**

# %% [markdown]
# # **Cidades presentes:**

# %%
df['cidade'].unique()
# Out:
# array(['Brasília', 'Curitiba', 'Salvador', 'Belo Horizonte', 'Recife',
#        'Fortaleza', 'Rio de Janeiro', 'Porto Alegre', 'Manaus',
#        'São Paulo'], dtype=object)

# %% [markdown]
# # **Média de poluição por cidade:**

# %%
df.groupby('cidade')[['pm25','pm10','no2','o3']].mean()
# Out:
#                      pm25       pm10        no2         o3
# cidade
# Belo Horizonte  27.874026  48.409091  27.992208  30.141558
# Brasília        31.351724  59.428736  29.926437  33.167816
# Curitiba        25.339785  43.408602  26.151613  28.435484
# Fortaleza       23.186250  44.662500  24.232500  34.176250
# Manaus          26.271084  46.898795  22.566265  30.354217
# Porto Alegre    26.798592  47.760563  27.959155  27.991549
# Recife          23.416471  41.165882  24.320000  32.205882
# Rio de Janeiro  27.825301  43.106024  30.925301  38.836145
# Salvador        21.503896  39.102597  24.568831  34.274026
# São Paulo       33.653125  56.256250  39.314062  34.878125

# %% [markdown]
# # **Perguntas**
# 1. Qual cidade apresenta maior média de PM2.5? R: São Paulo
# 2. Qual cidade apresenta maior média de NO2? R: São Paulo
# 3. Existe alguma cidade com níveis consistentemente mais altos de poluentes? R: São Paulo apresenta níveis consistentes

# %% [markdown]
# # **Parte 4 — Análise do índice de qualidade do ar**

# %% [markdown]
# # **A média do índice de qualidade do ar por cidade:**

# %%
df.groupby('cidade')['indice_qualidade_ar'].mean().sort_values(ascending=False)
# Out:
# cidade
# São Paulo         59.345312
# Brasília          54.955172
# Rio de Janeiro    50.639759
# Belo Horizonte    48.344156
# Porto Alegre      46.898592
# Manaus            45.092771
# Fortaleza         44.646250
# Curitiba          44.359140
# Recife            43.198824
# Salvador          42.342857
# Name: indice_qualidade_ar, dtype: float64

# %% [markdown]
# # **Perguntas**
# 1. Qual cidade apresenta pior qualidade média do ar?
# R: São Paulo
#
# 2. Qual cidade apresenta melhor qualidade do ar?
# R: Salvador

# %% [markdown]
# **Parte 5 — Filtragem por nível de alerta**

# %% [markdown]
# # **Filtro para Ruim ou Muito Ruim**

# %%
df_alerta = df[df['nivel_alerta'].isin(['Ruim','Muito Ruim'])]
df_alerta.head()
# Out:
#            data          cidade estado  pm25  pm10   no2    o3  temperatura  \
# 235  2025-04-20       São Paulo     SP  33.7  73.7  57.2  34.3         25.9
# 319  2025-06-01  Rio de Janeiro     RJ  45.1  70.1  37.4  48.0         28.1
# 320  2025-06-02          Manaus     AM  53.6  79.5  25.2  36.2         31.7
# 347  2025-06-17        Brasília     DF  52.7  79.1  35.4  31.9         28.6
# 358  2025-06-20  Belo Horizonte     MG  44.5  78.9  41.8  46.1         27.0
#
#      umidade  indice_qualidade_ar nivel_alerta
# 235     61.1                 70.8         Ruim
# 319     78.9                 72.7         Ruim
# 320     74.9                 71.6         Ruim
# 347     51.0                 73.5         Ruim
# 358     64.8                 75.9         Ruim

# %% [markdown]
# # **Perguntas**
# 1. Quantos registros possuem alerta crítico?
# R: Nenhuma cidade
# 2. Em quais cidades eles ocorrem com maior frequência?
# R: Em nenhuma cidade

# %%
df['nivel_alerta'].value_counts()
# Out:
# nivel_alerta
# Moderado    636
# Bom         150
# Ruim         14
# Name: count, dtype: int64

# %% [markdown]
# # **Parte 6 — Ranking dos dias mais críticos**

# %%
df.sort_values('indice_qualidade_ar', ascending=False).head(10)
# Out:
#            data          cidade estado  pm25  pm10   no2    o3  temperatura  \
# 488  2025-08-19       São Paulo     SP  55.2  78.8  55.0  45.3         20.3
# 431  2025-07-27       São Paulo     SP  60.1  50.0  56.4  54.8         25.2
# 410  2025-07-15       São Paulo     SP  42.4  87.6  44.6  40.2         21.2
# 379  2025-07-03       São Paulo     SP  51.7  78.9  48.3  26.8         21.6
# 358  2025-06-20  Belo Horizonte     MG  44.5  78.9  41.8  46.1         27.0
# 548  2025-09-17        Brasília     DF  54.3  69.2  37.4  36.0         23.8
# 347  2025-06-17        Brasília     DF  52.7  79.1  35.4  31.9         28.6
# 319  2025-06-01  Rio de Janeiro     RJ  45.1  70.1  37.4  48.0         28.1
# 411  2025-07-15       São Paulo     SP  35.8  91.6  41.6  36.7         22.4
# 320  2025-06-02          Manaus     AM  53.6  79.5  25.2  36.2         31.7
#
#      umidade  indice_qualidade_ar nivel_alerta
# 488     80.3                 86.3         Ruim
# 431     76.3                 84.3         Ruim
# 410     74.7                 76.5         Ruim
# 379     68.0                 76.1         Ruim
# 358     64.8                 75.9         Ruim
# 548     62.5                 73.6         Ruim
# 347     51.0                 73.5         Ruim
# 319     78.9                 72.7         Ruim
# 411     79.9                 71.8         Ruim
# 320     74.9                 71.6         Ruim
